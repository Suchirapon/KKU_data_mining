# %% [markdown]
# <a href="https://colab.research.google.com/github/Suchirapon/KKU_data_mining/blob/master/Association_Rules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive 
drive.mount('/content/drive')

path = '/content/drive/My Drive/DWDM_material'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
data = pd.read_csv(os.path.join(path,'reduced_marketbasket.csv'),encoding='latin1')
data
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 0         536365    85123A  ...    17850.0  United Kingdom
# 1         536365     71053  ...    17850.0  United Kingdom
# 2         536365    84406B  ...    17850.0  United Kingdom
# 3         536365    84029G  ...    17850.0  United Kingdom
# 4         536365    84029E  ...    17850.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 541904    581587     22613  ...    12680.0          France
# 541905    581587     22899  ...    12680.0          France
# 541906    581587     23254  ...    12680.0          France
# 541907    581587     23255  ...    12680.0          France
# 541908    581587     22138  ...    12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# EX ให้หาว่าแต่ละประเทศ ขายสินค้ารวมกันทั้งหมดได้ประเทศละกี่ชิ้น

# %%
# จากตาราง data เราจะ .groupby ประเทศ ('Country')
data_Country_Quantity = data.groupby('Country').sum().sort_values('Quantity',ascending=False)
data_Country_Quantity
#.sort_values เรียงจากน้อยไปมาก
#ascending=False เรียงจากมากไปน้อย
# Out:
#                       Quantity     UnitPrice    CustomerID
# Country
# United Kingdom         4263829  2.245715e+06  5.626433e+09
# Netherlands             200128  6.492550e+03  3.419054e+07
# EIRE                    142637  4.844719e+04  1.103917e+08
# Germany                 117448  3.766600e+04  1.200751e+08
# France                  110480  4.303199e+04  1.076489e+08
# Australia                83653  4.054750e+03  1.569300e+07
# Sweden                   35637  1.806830e+03  6.790083e+06
# Switzerland              30325  6.813690e+03  2.377592e+07
# Spain                    26824  1.263345e+04  3.268929e+07
# Japan                    25218  8.148600e+02  4.567292e+06
# Belgium                  23152  7.540130e+03  2.571829e+07
# Norway                   19247  6.529060e+03  1.350765e+07
# Portugal                 16180  1.303754e+04  1.886480e+07
# Finland                  10666  3.786850e+03  8.699324e+06
# Channel Islands           9479  3.738550e+03  1.128522e+07
# ...

# %% [markdown]
# คำสั่งพิเศษของ groupby คือ __.apply(list)__ คือ การแปลงข้อมูลในเป็น list

# %%
transacs = data.groupby('InvoiceNo')['StockCode'].apply(list)
transacs 
#ตัว c ใน InvoiceNo คือการลบสินค้าออกไป
# Out:
# InvoiceNo
# 536365     [85123A, 71053, 84406B, 84029G, 84029E, 22752,...
# 536366                                        [22633, 22632]
# 536367     [84879, 22745, 22748, 22749, 22310, 84969, 226...
# 536368                          [22960, 22913, 22912, 22914]
# 536369                                               [21756]
#                                  ...
# C581484                                              [23843]
# C581490                                       [22178, 23144]
# C581499                                                  [M]
# C581568                                              [21258]
# C581569                                       [84978, 20979]
# Name: StockCode, Length: 25900, dtype: object

# %% [markdown]
# ## Apriori

# %%
# !pip install apyori
# ทำการติดตั้งแพ็คเกจ apyori
# Out:
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-cp36-none-any.whl size=5975 sha256=9806816128419587069f002212f9385abd3f727c48a0059c7c8aacba35867c90
#   Stored in directory: /root/.cache/pip/wheels/5d/92/bb/474bbadbc8c0062b9eb168f69982a0443263f8ab1711a8cad0
# Successfully built apyori
# ...

# %%
from apyori import apriori

# %%
list(apriori(transacs,min_support = 0.02, min_cofidence = 0.1))
# min_support = 0.02 คือ กำหนดให้เท่า 0.02 แปลว่า ทุกกฎที่โผล่มา transacs เกิดขึ้นซ้ำๆประมาณ 500 คือ 0.02 คูณกับ Row 25900
# min_cofidence = 0.1 คือ เอา sup มาหารด้วย sup แต่ละอัน
# Out:
# [RelationRecord(items=frozenset({'15036'}), support=0.020193050193050194, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'15036'}), confidence=0.020193050193050194, lift=1.0)]),
#  RelationRecord(items=frozenset({'20685'}), support=0.027181467181467182, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20685'}), confidence=0.027181467181467182, lift=1.0)]),
#  RelationRecord(items=frozenset({'20711'}), support=0.02054054054054054, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20711'}), confidence=0.02054054054054054, lift=1.0)]),
#  RelationRecord(items=frozenset({'20712'}), support=0.033667953667953665, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20712'}), confidence=0.033667953667953665, lift=1.0)]),
# ...

# %% [markdown]
# #QUIZ หา k- itemset ที่มีความน่าสนใจพร้อมทั้งอธิบายว่าน่าสนใจยังไง

# %%
transacsCusID = data.groupby('CustomerID')['StockCode'].apply(list)
transacsCusID
# Out:
# CustomerID
# 12346.0                                       [23166, 23166]
# 12347.0    [85116, 22375, 71477, 22492, 22771, 22772, 227...
# 12348.0    [84992, 22951, 84991, 84991, 21213, 21213, 226...
# 12349.0    [23112, 23460, 21564, 21411, 21563, 22131, 221...
# 12350.0    [21908, 22412, 79066K, 79191C, 22348, 84086C, ...
#                                  ...
# 18280.0    [82484, 22180, 22467, 22725, 22727, 22495, 223...
# 18281.0    [22037, 22716, 22028, 23007, 23008, 23209, 22467]
# 18282.0    [21270, 23187, 23295, 22089, 21108, 21109, 224...
# 18283.0    [22356, 20726, 22384, 22386, 20717, 20718, 850...
# 18287.0    [22755, 22754, 22753, 22756, 22758, 22757, 227...
# Name: StockCode, Length: 4372, dtype: object

# %%
list(apriori(transacsCusID,min_support = 0.03, min_cofidence = 0.02))
# Out:
# [RelationRecord(items=frozenset({'15036'}), support=0.04437328453796889, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'15036'}), confidence=0.04437328453796889, lift=1.0)]),
#  RelationRecord(items=frozenset({'15056BL'}), support=0.032479414455626715, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'15056BL'}), confidence=0.032479414455626715, lift=1.0)]),
#  RelationRecord(items=frozenset({'15056N'}), support=0.042086001829826164, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'15056N'}), confidence=0.042086001829826164, lift=1.0)]),
#  RelationRecord(items=frozenset({'16156S'}), support=0.030878316559926806, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'16156S'}), confidence=0.030878316559926806, lift=1.0)]),
# ...
