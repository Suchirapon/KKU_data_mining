# %% [markdown]
# <a href="https://colab.research.google.com/github/Suchirapon/KKU_data_mining/blob/master/Project_Mining_Zoo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # อธิบายข้อมูล

# %% [markdown]
# # เรียกใช้ไฟล์

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/DataMining_Project'

# %%
import os
import pandas as pd
zoo_type = os.path.join(path,'zoo.csv')  
class_type = os.path.join(path,'class.csv')
zoo_type_df = pd.read_csv(zoo_type)
class_type_df = pd.read_csv(class_type)

# %%
zoo_type_df.head()
# Out:
#   animal_name  hair  feathers  eggs  ...  tail  domestic  catsize  class_type
# 0    aardvark     1         0     0  ...     0         0        1           1
# 1    antelope     1         0     0  ...     1         0        1           1
# 2        bass     0         0     1  ...     1         0        0           4
# 3        bear     1         0     0  ...     0         0        1           1
# 4        boar     1         0     0  ...     1         0        1           1
#
# [5 rows x 18 columns]

# %%
class_type_df
# Out:
#    Class_Number  ...                                       Animal_Names
# 0             1  ...  aardvark, antelope, bear, boar, buffalo, calf,...
# 1             2  ...  chicken, crow, dove, duck, flamingo, gull, haw...
# 2             3  ...    pitviper, seasnake, slowworm, tortoise, tuatara
# 3             4  ...  bass, carp, catfish, chub, dogfish, haddock, h...
# 4             5  ...                             frog, frog, newt, toad
# 5             6  ...  flea, gnat, honeybee, housefly, ladybird, moth...
# 6             7  ...  clam, crab, crayfish, lobster, octopus, scorpi...
#
# [7 rows x 4 columns]

# %% [markdown]
# # ทำการเเตรียมข้อมูล

# %%
from pandas.api.types import CategoricalDtype

# %% [markdown]
# ###แบ่งกลุ่มลักษณะของสัตว์ทั้งหมด 16 ลักษณะ จากไฟล์ข้อมูล zoo_type_df

# %%
zoo_type1 = zoo_type_df

# %%
h_bucket = ['nohair','hair']
zoo_type1['hair_group'] = pd.cut(zoo_type1.hair,
                            bins=[0,1,2],
                            labels=h_bucket,
                            right=False).astype(str).astype(CategoricalDtype(h_bucket,ordered=True))
zoo_type1
# Out:
#     animal_name  hair  feathers  eggs  ...  domestic  catsize  class_type  hair_group
# 0      aardvark     1         0     0  ...         0        1           1        hair
# 1      antelope     1         0     0  ...         0        1           1        hair
# 2          bass     0         0     1  ...         0        0           4      nohair
# 3          bear     1         0     0  ...         0        1           1        hair
# 4          boar     1         0     0  ...         0        1           1        hair
# ..          ...   ...       ...   ...  ...       ...      ...         ...         ...
# 96      wallaby     1         0     0  ...         0        1           1        hair
# 97         wasp     1         0     1  ...         0        0           6        hair
# 98         wolf     1         0     0  ...         0        1           1        hair
# 99         worm     0         0     1  ...         0        0           7      nohair
# 100        wren     0         1     1  ...         0        0           2      nohair
#
# [101 rows x 19 columns]

# %%
f_bucket = ['nofeathers','feathers']
zoo_type1['feathers_group'] = pd.cut(zoo_type1.feathers,
                            bins=[0,1,2],
                            labels=f_bucket,
                            right=False).astype(str).astype(CategoricalDtype(f_bucket,ordered=True))
zoo_type1
# Out:
#     animal_name  hair  feathers  ...  class_type  hair_group  feathers_group
# 0      aardvark     1         0  ...           1        hair      nofeathers
# 1      antelope     1         0  ...           1        hair      nofeathers
# 2          bass     0         0  ...           4      nohair      nofeathers
# 3          bear     1         0  ...           1        hair      nofeathers
# 4          boar     1         0  ...           1        hair      nofeathers
# ..          ...   ...       ...  ...         ...         ...             ...
# 96      wallaby     1         0  ...           1        hair      nofeathers
# 97         wasp     1         0  ...           6        hair      nofeathers
# 98         wolf     1         0  ...           1        hair      nofeathers
# 99         worm     0         0  ...           7      nohair      nofeathers
# 100        wren     0         1  ...           2      nohair        feathers
#
# [101 rows x 20 columns]

# %%
e_bucket = ['noeggs','eggs']
zoo_type1['eggs_group'] = pd.cut(zoo_type1.eggs,
                            bins=[0,1,2],
                            labels=e_bucket,
                            right=False).astype(str).astype(CategoricalDtype(e_bucket,ordered=True))
zoo_type1
# Out:
#     animal_name  hair  feathers  ...  hair_group  feathers_group  eggs_group
# 0      aardvark     1         0  ...        hair      nofeathers      noeggs
# 1      antelope     1         0  ...        hair      nofeathers      noeggs
# 2          bass     0         0  ...      nohair      nofeathers        eggs
# 3          bear     1         0  ...        hair      nofeathers      noeggs
# 4          boar     1         0  ...        hair      nofeathers      noeggs
# ..          ...   ...       ...  ...         ...             ...         ...
# 96      wallaby     1         0  ...        hair      nofeathers      noeggs
# 97         wasp     1         0  ...        hair      nofeathers        eggs
# 98         wolf     1         0  ...        hair      nofeathers      noeggs
# 99         worm     0         0  ...      nohair      nofeathers        eggs
# 100        wren     0         1  ...      nohair        feathers        eggs
#
# [101 rows x 21 columns]

# %%
m_bucket = ['nomilk','milk']
zoo_type1['milk_group'] = pd.cut(zoo_type1.milk,
                            bins=[0,1,2],
                            labels=m_bucket,
                            right=False).astype(str).astype(CategoricalDtype(m_bucket,ordered=True))
zoo_type1
# Out:
#     animal_name  hair  feathers  ...  feathers_group  eggs_group  milk_group
# 0      aardvark     1         0  ...      nofeathers      noeggs        milk
# 1      antelope     1         0  ...      nofeathers      noeggs        milk
# 2          bass     0         0  ...      nofeathers        eggs      nomilk
# 3          bear     1         0  ...      nofeathers      noeggs        milk
# 4          boar     1         0  ...      nofeathers      noeggs        milk
# ..          ...   ...       ...  ...             ...         ...         ...
# 96      wallaby     1         0  ...      nofeathers      noeggs        milk
# 97         wasp     1         0  ...      nofeathers        eggs      nomilk
# 98         wolf     1         0  ...      nofeathers      noeggs        milk
# 99         worm     0         0  ...      nofeathers        eggs      nomilk
# 100        wren     0         1  ...        feathers        eggs      nomilk
#
# [101 rows x 22 columns]

# %%
a_bucket = ['noairborne','airborne']
zoo_type1['airborne_group'] = pd.cut(zoo_type1.airborne,
                            bins=[0,1,2],
                            labels=a_bucket,
                            right=False).astype(str).astype(CategoricalDtype(a_bucket,ordered=True))
zoo_type1
# Out:
#     animal_name  hair  feathers  ...  eggs_group  milk_group  airborne_group
# 0      aardvark     1         0  ...      noeggs        milk      noairborne
# 1      antelope     1         0  ...      noeggs        milk      noairborne
# 2          bass     0         0  ...        eggs      nomilk      noairborne
# 3          bear     1         0  ...      noeggs        milk      noairborne
# 4          boar     1         0  ...      noeggs        milk      noairborne
# ..          ...   ...       ...  ...         ...         ...             ...
# 96      wallaby     1         0  ...      noeggs        milk      noairborne
# 97         wasp     1         0  ...        eggs      nomilk        airborne
# 98         wolf     1         0  ...      noeggs        milk      noairborne
# 99         worm     0         0  ...        eggs      nomilk      noairborne
# 100        wren     0         1  ...        eggs      nomilk        airborne
#
# [101 rows x 23 columns]

# %%
a_bucket = ['noaquatic','aquatic']
zoo_type1['aquatic_group'] = pd.cut(zoo_type1.aquatic,
                            bins=[0,1,2],
                            labels=a_bucket,
                            right=False).astype(str).astype(CategoricalDtype(a_bucket,ordered=True))
zoo_type1
# Out:
#     animal_name  hair  feathers  ...  milk_group  airborne_group  aquatic_group
# 0      aardvark     1         0  ...        milk      noairborne      noaquatic
# 1      antelope     1         0  ...        milk      noairborne      noaquatic
# 2          bass     0         0  ...      nomilk      noairborne        aquatic
# 3          bear     1         0  ...        milk      noairborne      noaquatic
# 4          boar     1         0  ...        milk      noairborne      noaquatic
# ..          ...   ...       ...  ...         ...             ...            ...
# 96      wallaby     1         0  ...        milk      noairborne      noaquatic
# 97         wasp     1         0  ...      nomilk        airborne      noaquatic
# 98         wolf     1         0  ...        milk      noairborne      noaquatic
# 99         worm     0         0  ...      nomilk      noairborne      noaquatic
# 100        wren     0         1  ...      nomilk        airborne      noaquatic
#
# [101 rows x 24 columns]

# %%
p_bucket = ['nopredator','predator']
zoo_type1['predator_group'] = pd.cut(zoo_type1.predator,
                            bins=[0,1,2],
                            labels=p_bucket,
                            right=False).astype(str).astype(CategoricalDtype(p_bucket,ordered=True))
zoo_type1
# Out:
#     animal_name  hair  feathers  ...  airborne_group  aquatic_group  predator_group
# 0      aardvark     1         0  ...      noairborne      noaquatic        predator
# 1      antelope     1         0  ...      noairborne      noaquatic      nopredator
# 2          bass     0         0  ...      noairborne        aquatic        predator
# 3          bear     1         0  ...      noairborne      noaquatic        predator
# 4          boar     1         0  ...      noairborne      noaquatic        predator
# ..          ...   ...       ...  ...             ...            ...             ...
# 96      wallaby     1         0  ...      noairborne      noaquatic      nopredator
# 97         wasp     1         0  ...        airborne      noaquatic      nopredator
# 98         wolf     1         0  ...      noairborne      noaquatic        predator
# 99         worm     0         0  ...      noairborne      noaquatic      nopredator
# 100        wren     0         1  ...        airborne      noaquatic      nopredator
#
# [101 rows x 25 columns]

# %%
t_bucket = ['notoothed','toothed']
zoo_type1['toothed_group'] = pd.cut(zoo_type1.toothed,
                            bins=[0,1,2],
                            labels=t_bucket,
                            right=False).astype(str).astype(CategoricalDtype(t_bucket,ordered=True))
zoo_type1
# Out:
#     animal_name  hair  feathers  ...  aquatic_group  predator_group  toothed_group
# 0      aardvark     1         0  ...      noaquatic        predator        toothed
# 1      antelope     1         0  ...      noaquatic      nopredator        toothed
# 2          bass     0         0  ...        aquatic        predator        toothed
# 3          bear     1         0  ...      noaquatic        predator        toothed
# 4          boar     1         0  ...      noaquatic        predator        toothed
# ..          ...   ...       ...  ...            ...             ...            ...
# 96      wallaby     1         0  ...      noaquatic      nopredator        toothed
# 97         wasp     1         0  ...      noaquatic      nopredator      notoothed
# 98         wolf     1         0  ...      noaquatic        predator        toothed
# 99         worm     0         0  ...      noaquatic      nopredator      notoothed
# 100        wren     0         1  ...      noaquatic      nopredator      notoothed
#
# [101 rows x 26 columns]

# %%
b_bucket = ['nobackbone','backbone']
zoo_type1['backbone_group'] = pd.cut(zoo_type1.backbone,
                            bins=[0,1,2],
                            labels=b_bucket,
                            right=False).astype(str).astype(CategoricalDtype(b_bucket,ordered=True))
zoo_type1
# Out:
#     animal_name  hair  feathers  ...  predator_group  toothed_group  backbone_group
# 0      aardvark     1         0  ...        predator        toothed        backbone
# 1      antelope     1         0  ...      nopredator        toothed        backbone
# 2          bass     0         0  ...        predator        toothed        backbone
# 3          bear     1         0  ...        predator        toothed        backbone
# 4          boar     1         0  ...        predator        toothed        backbone
# ..          ...   ...       ...  ...             ...            ...             ...
# 96      wallaby     1         0  ...      nopredator        toothed        backbone
# 97         wasp     1         0  ...      nopredator      notoothed      nobackbone
# 98         wolf     1         0  ...        predator        toothed        backbone
# 99         worm     0         0  ...      nopredator      notoothed      nobackbone
# 100        wren     0         1  ...      nopredator      notoothed        backbone
#
# [101 rows x 27 columns]

# %%
b_bucket = ['nobreathes','breathes']
zoo_type1['breathes_group'] = pd.cut(zoo_type1.breathes,
                            bins=[0,1,2],
                            labels=b_bucket,
                            right=False).astype(str).astype(CategoricalDtype(b_bucket,ordered=True))
zoo_type1
# Out:
#     animal_name  hair  feathers  ...  toothed_group  backbone_group  breathes_group
# 0      aardvark     1         0  ...        toothed        backbone        breathes
# 1      antelope     1         0  ...        toothed        backbone        breathes
# 2          bass     0         0  ...        toothed        backbone      nobreathes
# 3          bear     1         0  ...        toothed        backbone        breathes
# 4          boar     1         0  ...        toothed        backbone        breathes
# ..          ...   ...       ...  ...            ...             ...             ...
# 96      wallaby     1         0  ...        toothed        backbone        breathes
# 97         wasp     1         0  ...      notoothed      nobackbone        breathes
# 98         wolf     1         0  ...        toothed        backbone        breathes
# 99         worm     0         0  ...      notoothed      nobackbone        breathes
# 100        wren     0         1  ...      notoothed        backbone        breathes
#
# [101 rows x 28 columns]

# %%
v_bucket = ['novenomous','venomous']
zoo_type1['venomous_group'] = pd.cut(zoo_type1.venomous,
                            bins=[0,1,2],
                            labels=v_bucket,
                            right=False).astype(str).astype(CategoricalDtype(v_bucket,ordered=True))
zoo_type1
# Out:
#     animal_name  hair  feathers  ...  backbone_group  breathes_group  venomous_group
# 0      aardvark     1         0  ...        backbone        breathes      novenomous
# 1      antelope     1         0  ...        backbone        breathes      novenomous
# 2          bass     0         0  ...        backbone      nobreathes      novenomous
# 3          bear     1         0  ...        backbone        breathes      novenomous
# 4          boar     1         0  ...        backbone        breathes      novenomous
# ..          ...   ...       ...  ...             ...             ...             ...
# 96      wallaby     1         0  ...        backbone        breathes      novenomous
# 97         wasp     1         0  ...      nobackbone        breathes        venomous
# 98         wolf     1         0  ...        backbone        breathes      novenomous
# 99         worm     0         0  ...      nobackbone        breathes      novenomous
# 100        wren     0         1  ...        backbone        breathes      novenomous
#
# [101 rows x 29 columns]

# %%
f_bucket = ['nofins','fins']
zoo_type1['fins_group'] = pd.cut(zoo_type1.	fins,
                            bins=[0,1,2],
                            labels=f_bucket,
                            right=False).astype(str).astype(CategoricalDtype(f_bucket,ordered=True))
zoo_type1
# Out:
#     animal_name  hair  feathers  ...  breathes_group  venomous_group  fins_group
# 0      aardvark     1         0  ...        breathes      novenomous      nofins
# 1      antelope     1         0  ...        breathes      novenomous      nofins
# 2          bass     0         0  ...      nobreathes      novenomous        fins
# 3          bear     1         0  ...        breathes      novenomous      nofins
# 4          boar     1         0  ...        breathes      novenomous      nofins
# ..          ...   ...       ...  ...             ...             ...         ...
# 96      wallaby     1         0  ...        breathes      novenomous      nofins
# 97         wasp     1         0  ...        breathes        venomous      nofins
# 98         wolf     1         0  ...        breathes      novenomous      nofins
# 99         worm     0         0  ...        breathes      novenomous      nofins
# 100        wren     0         1  ...        breathes      novenomous      nofins
#
# [101 rows x 30 columns]

# %%
l_bucket = ['nolegs','2legs','4legs','6legs','8legs']
zoo_type1['legs_group'] = pd.cut(zoo_type1.	legs,
                            bins=[0,2,4,6,7,9],
                            labels=l_bucket,
                            right=False).astype(str).astype(CategoricalDtype(l_bucket,ordered=True))
zoo_type1
# Out:
#     animal_name  hair  feathers  ...  venomous_group  fins_group  legs_group
# 0      aardvark     1         0  ...      novenomous      nofins       4legs
# 1      antelope     1         0  ...      novenomous      nofins       4legs
# 2          bass     0         0  ...      novenomous        fins      nolegs
# 3          bear     1         0  ...      novenomous      nofins       4legs
# 4          boar     1         0  ...      novenomous      nofins       4legs
# ..          ...   ...       ...  ...             ...         ...         ...
# 96      wallaby     1         0  ...      novenomous      nofins       2legs
# 97         wasp     1         0  ...        venomous      nofins       6legs
# 98         wolf     1         0  ...      novenomous      nofins       4legs
# 99         worm     0         0  ...      novenomous      nofins      nolegs
# 100        wren     0         1  ...      novenomous      nofins       2legs
#
# [101 rows x 31 columns]

# %%
t_bucket = ['notail','tail']
zoo_type1['tail_group'] = pd.cut(zoo_type1.tail,
                            bins=[0,2,4,6,7,9],
                            labels=t_bucket,
                            right=False).astype(str).astype(CategoricalDtype(t_bucket,ordered=True))
zoo_type1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-e787c129585f> in <module>()
#       3                             bins=[0,2,4,6,7,9],
#       4                             labels=t_bucket,
# ----> 5                             right=False).astype(str).astype(CategoricalDtype(t_bucket,ordered=True))
#       6 zoo_type1
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     222
#     223     original = x
# --> 224     x = _preprocess_for_cut(x)
#     225     x, dtype = _coerce_to_type(x)
#     226
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/tile.py in _preprocess_for_cut(x)
#     578         x = np.asarray(x)
#     579     if x.ndim != 1:
# --> 580         raise ValueError("Input array must be 1 dimensional")
#     581
#     582     return x
#
# ValueError: Input array must be 1 dimensional

# %% [markdown]
# ### เนื่องจากคอลัมลักษณะ tail Error Input array must be 1 dimensional จึงทำการวนลูปค่า

# %%
for i in range(len(zoo_type1)):
  print(zoo_type1['tail'][i])

# %%
for i in range(len(zoo_type1)):
  if zoo_type1['tail'][i] == 0:
    zoo_type1['tail_group'] = 'notail'
  else:
    zoo_type1['tail_group'] = 'tail'

# %%
d_bucket = ['nodomestic','domestic']
zoo_type1['domestic_group'] = pd.cut(zoo_type1.domestic,
                            bins=[0,1,2],
                            labels=d_bucket,
                            right=False).astype(str).astype(CategoricalDtype(d_bucket,ordered=True))
zoo_type1
# Out:
#     animal_name  hair  feathers  ...  tail_group  catsize_group  domestic_group
# 0      aardvark     1         0  ...        tail        catsize      nodomestic
# 1      antelope     1         0  ...        tail        catsize      nodomestic
# 2          bass     0         0  ...        tail      nocatsize      nodomestic
# 3          bear     1         0  ...        tail        catsize      nodomestic
# 4          boar     1         0  ...        tail        catsize      nodomestic
# ..          ...   ...       ...  ...         ...            ...             ...
# 96      wallaby     1         0  ...        tail        catsize      nodomestic
# 97         wasp     1         0  ...        tail      nocatsize      nodomestic
# 98         wolf     1         0  ...        tail        catsize      nodomestic
# 99         worm     0         0  ...        tail      nocatsize      nodomestic
# 100        wren     0         1  ...        tail      nocatsize      nodomestic
#
# [101 rows x 34 columns]

# %%
c_bucket = ['nocatsize','catsize']
zoo_type1['catsize_group'] = pd.cut(zoo_type1.catsize,
                            bins=[0,1,2],
                            labels=c_bucket,
                            right=False).astype(str).astype(CategoricalDtype(c_bucket,ordered=True))
zoo_type1
# Out:
#     animal_name  hair  feathers  ...  tail_group  catsize_group  domestic_group
# 0      aardvark     1         0  ...        tail        catsize      nodomestic
# 1      antelope     1         0  ...        tail        catsize      nodomestic
# 2          bass     0         0  ...        tail      nocatsize      nodomestic
# 3          bear     1         0  ...        tail        catsize      nodomestic
# 4          boar     1         0  ...        tail        catsize      nodomestic
# ..          ...   ...       ...  ...         ...            ...             ...
# 96      wallaby     1         0  ...        tail        catsize      nodomestic
# 97         wasp     1         0  ...        tail      nocatsize      nodomestic
# 98         wolf     1         0  ...        tail        catsize      nodomestic
# 99         worm     0         0  ...        tail      nocatsize      nodomestic
# 100        wren     0         1  ...        tail      nocatsize      nodomestic
#
# [101 rows x 34 columns]

# %% [markdown]
# # Association ของแต่ละลักษณะ

# %%
# !pip install apyori
import numpy as np
import matplotlib.pyplot as plt
from apyori import apriori
# Out:
# Collecting apyori
#   Downloading https://files.pythonhosted.org/packages/5e/62/5ffde5c473ea4b033490617ec5caa80d59804875ad3c3c57c0976533a21a/apyori-1.1.2.tar.gz
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-cp36-none-any.whl size=5975 sha256=deb665883f89228b726fdc33577e15cba1090a5cf5e655fe235ae03cce2304f3
#   Stored in directory: /root/.cache/pip/wheels/5d/92/bb/474bbadbc8c0062b9eb168f69982a0443263f8ab1711a8cad0
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
zoo_type1
# Out:
#     animal_name  hair  feathers  ...  tail_group  catsize_group  domestic_group
# 0      aardvark     1         0  ...        tail        catsize      nodomestic
# 1      antelope     1         0  ...        tail        catsize      nodomestic
# 2          bass     0         0  ...        tail      nocatsize      nodomestic
# 3          bear     1         0  ...        tail        catsize      nodomestic
# 4          boar     1         0  ...        tail        catsize      nodomestic
# ..          ...   ...       ...  ...         ...            ...             ...
# 96      wallaby     1         0  ...        tail        catsize      nodomestic
# 97         wasp     1         0  ...        tail      nocatsize      nodomestic
# 98         wolf     1         0  ...        tail        catsize      nodomestic
# 99         worm     0         0  ...        tail      nocatsize      nodomestic
# 100        wren     0         1  ...        tail      nocatsize      nodomestic
#
# [101 rows x 34 columns]

# %% [markdown]
# ### ทำการดึงตารางที่ต้องการออกมาให้อยู่ในตัวแปร zoo_type2

# %%
zoo_type2 = zoo_type1[['animal_name','hair_group','feathers_group', 'eggs_group', 'milk_group', 'airborne_group', 'aquatic_group', 'predator_group', 'toothed_group', 'backbone_group', 'breathes_group', 'venomous_group', 'fins_group', 'legs_group','tail_group', 'domestic_group', 'catsize_group' ]]
zoo_type2
# Out:
#     animal_name hair_group  ... domestic_group catsize_group
# 0      aardvark       hair  ...     nodomestic       catsize
# 1      antelope       hair  ...     nodomestic       catsize
# 2          bass     nohair  ...     nodomestic     nocatsize
# 3          bear       hair  ...     nodomestic       catsize
# 4          boar       hair  ...     nodomestic       catsize
# ..          ...        ...  ...            ...           ...
# 96      wallaby       hair  ...     nodomestic       catsize
# 97         wasp       hair  ...     nodomestic     nocatsize
# 98         wolf       hair  ...     nodomestic       catsize
# 99         worm     nohair  ...     nodomestic     nocatsize
# 100        wren     nohair  ...     nodomestic     nocatsize
#
# [101 rows x 17 columns]

# %%
zoo_type2.isnull().any().any()
# Out:
# False

# %%
#Convert data to list
transacs = []
for i in range(0,len(zoo_type2)):
  transacs.append([str(zoo_type2.values[i,j]) for j in range(1,17)])
transacs
# Out:
# [['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '8legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'noeggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '8legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'noeggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'venomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize']]

# %%
asso = list(apriori(transacs,min_support = 0.8, min_confidence = 0.7))
asso
# Out:
# [RelationRecord(items=frozenset({'backbone'}), support=0.8217821782178217, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'backbone'}), confidence=0.8217821782178217, lift=1.0)]),
#  RelationRecord(items=frozenset({'nodomestic'}), support=0.8712871287128713, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nodomestic'}), confidence=0.8712871287128713, lift=1.0)]),
#  RelationRecord(items=frozenset({'nofeathers'}), support=0.801980198019802, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nofeathers'}), confidence=0.801980198019802, lift=1.0)]),
#  RelationRecord(items=frozenset({'nofins'}), support=0.8316831683168316, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nofins'}), confidence=0.8316831683168316, lift=1.0)]),
#  RelationRecord(items=frozenset({'novenomous'}), support=0.9207920792079208, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'novenomous'}), confidence=0.9207920792079208, lift=1.0)]),
#  RelationRecord(items=frozenset({'tail'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'tail'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'backbone', 'tail'}), support=0.8217821782178217, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'backbone', 'tail'}), confidence=0.8217821782178217, lift=1.0), OrderedStatistic(items_base=frozenset({'backbone'}), items_add=frozenset({'tail'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'tail'}), items_add=frozenset({'backbone'}), confidence=0.8217821782178217, lift=1.0)]),
#  RelationRecord(items=frozenset({'nodomestic', 'novenomous'}), support=0.801980198019802, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nodomestic', 'novenomous'}), confidence=0.801980198019802, lift=1.0), OrderedStatistic(items_base=frozenset({'nodomestic'}), items_add=frozenset({'novenomous'}), confidence=0.9204545454545455, lift=0.999633431085044), OrderedStatistic(items_base=frozenset({'novenomous'}), items_add=frozenset({'nodomestic'}), confidence=0.8709677419354839, lift=0.999633431085044)]),
#  RelationRecord(items=frozenset({'nodomestic', 'tail'}), support=0.8712871287128713, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nodomestic', 'tail'}), confidence=0.8712871287128713, lift=1.0), OrderedStatistic(items_base=frozenset({'nodomestic'}), items_add=frozenset({'tail'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'tail'}), items_add=frozenset({'nodomestic'}), confidence=0.8712871287128713, lift=1.0)]),
#  RelationRecord(items=frozenset({'tail', 'nofeathers'}), support=0.801980198019802, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'tail', 'nofeathers'}), confidence=0.801980198019802, lift=1.0), OrderedStatistic(items_base=frozenset({'nofeathers'}), items_add=frozenset({'tail'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'tail'}), items_add=frozenset({'nofeathers'}), confidence=0.801980198019802, lift=1.0)]),
#  RelationRecord(items=frozenset({'tail', 'nofins'}), support=0.8316831683168316, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'tail', 'nofins'}), confidence=0.8316831683168316, lift=1.0), OrderedStatistic(items_base=frozenset({'nofins'}), items_add=frozenset({'tail'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'tail'}), items_add=frozenset({'nofins'}), confidence=0.8316831683168316, lift=1.0)]),
#  RelationRecord(items=frozenset({'tail', 'novenomous'}), support=0.9207920792079208, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'tail', 'novenomous'}), confidence=0.9207920792079208, lift=1.0), OrderedStatistic(items_base=frozenset({'novenomous'}), items_add=frozenset({'tail'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'tail'}), items_add=frozenset({'novenomous'}), confidence=0.9207920792079208, lift=1.0)]),
#  RelationRecord(items=frozenset({'nodomestic', 'tail', 'novenomous'}), support=0.801980198019802, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nodomestic', 'tail', 'novenomous'}), confidence=0.801980198019802, lift=1.0), OrderedStatistic(items_base=frozenset({'nodomestic'}), items_add=frozenset({'tail', 'novenomous'}), confidence=0.9204545454545455, lift=0.999633431085044), OrderedStatistic(items_base=frozenset({'novenomous'}), items_add=frozenset({'nodomestic', 'tail'}), confidence=0.8709677419354839, lift=0.999633431085044), OrderedStatistic(items_base=frozenset({'tail'}), items_add=frozenset({'nodomestic', 'novenomous'}), confidence=0.801980198019802, lift=1.0), OrderedStatistic(items_base=frozenset({'nodomestic', 'novenomous'}), items_add=frozenset({'tail'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'nodomestic', 'tail'}), items_add=frozenset({'novenomous'}), confidence=0.9204545454545455, lift=0.999633431085044), OrderedStatistic(items_base=frozenset({'tail', 'novenomous'}), items_add=frozenset({'nodomestic'}), confidence=0.8709677419354839, lift=0.999633431085044)])]

# %% [markdown]
# # Association ของแต่ะละประเภท

# %% [markdown]
# ### ดึงส่วนของข้อมูลที่ทำการเปลี่ยนค่าแล้วออกมา

# %%
class_zoo = zoo_type1[['class_type','animal_name','hair_group','feathers_group', 'eggs_group', 'milk_group', 'airborne_group', 'aquatic_group', 'predator_group', 'toothed_group', 'backbone_group', 'breathes_group', 'venomous_group', 'fins_group', 'legs_group','tail_group', 'domestic_group', 'catsize_group' ]]
class_zoo.head()
# Out:
#    class_type animal_name hair_group  ... tail_group domestic_group catsize_group
# 0           1    aardvark       hair  ...       tail     nodomestic       catsize
# 1           1    antelope       hair  ...       tail     nodomestic       catsize
# 2           4        bass     nohair  ...       tail     nodomestic     nocatsize
# 3           1        bear       hair  ...       tail     nodomestic       catsize
# 4           1        boar       hair  ...       tail     nodomestic       catsize
#
# [5 rows x 18 columns]

# %% [markdown]
# ### ทำการรวมตาราง

# %%
class_z_merged = class_zoo.merge(class_type_df,how='left',left_on='class_type',right_on='Class_Number')
class_z_merged.head()
# Out:
#    class_type  ...                                       Animal_Names
# 0           1  ...  aardvark, antelope, bear, boar, buffalo, calf,...
# 1           1  ...  aardvark, antelope, bear, boar, buffalo, calf,...
# 2           4  ...  bass, carp, catfish, chub, dogfish, haddock, h...
# 3           1  ...  aardvark, antelope, bear, boar, buffalo, calf,...
# 4           1  ...  aardvark, antelope, bear, boar, buffalo, calf,...
#
# [5 rows x 22 columns]

# %% [markdown]
# ### ตัดตารางบางส่วนที่ไม่ได้ใช้ออก

# %%
class_z_merged_dr = class_z_merged.drop(['Class_Number','Number_Of_Animal_Species_In_Class','class_type','animal_name','Animal_Names'],axis=1)
class_z_merged_dr.head()
# Out:
#   hair_group feathers_group eggs_group  ... domestic_group catsize_group Class_Type
# 0       hair     nofeathers     noeggs  ...     nodomestic       catsize     Mammal
# 1       hair     nofeathers     noeggs  ...     nodomestic       catsize     Mammal
# 2     nohair     nofeathers       eggs  ...     nodomestic     nocatsize       Fish
# 3       hair     nofeathers     noeggs  ...     nodomestic       catsize     Mammal
# 4       hair     nofeathers     noeggs  ...     nodomestic       catsize     Mammal
#
# [5 rows x 17 columns]

# %% [markdown]
# ## Association ของสัตว์ประเภท Mammal

# %%
class_Mammal = class_z_merged_dr[class_z_merged_dr['Class_Type']=='Mammal']
class_Mammal.head()
# Out:
#   hair_group feathers_group eggs_group  ... domestic_group catsize_group Class_Type
# 0       hair     nofeathers     noeggs  ...     nodomestic       catsize     Mammal
# 1       hair     nofeathers     noeggs  ...     nodomestic       catsize     Mammal
# 3       hair     nofeathers     noeggs  ...     nodomestic       catsize     Mammal
# 4       hair     nofeathers     noeggs  ...     nodomestic       catsize     Mammal
# 5       hair     nofeathers     noeggs  ...     nodomestic       catsize     Mammal
#
# [5 rows x 17 columns]

# %%
transacs_class_Mammal = []
for i in range(0,len(class_Mammal)):
  transacs.append([str(class_Mammal.values[i,j]) for j in range(1,16)])
transacs

# %%
asso_class_Mammal = list(apriori(transacs_class_Mammal,min_support = 0.001, min_confidence = 0.1))
asso_class_Mammal
# Out:
# []

# %% [markdown]
# ## Association ของสัตว์ประเภท Fish

# %%
class_Fish = class_z_merged_dr[class_z_merged_dr['Class_Type']=='Fish']
class_Fish.head()
# Out:
#    hair_group feathers_group eggs_group  ... domestic_group catsize_group Class_Type
# 2      nohair     nofeathers       eggs  ...     nodomestic     nocatsize       Fish
# 7      nohair     nofeathers       eggs  ...       domestic     nocatsize       Fish
# 8      nohair     nofeathers       eggs  ...     nodomestic     nocatsize       Fish
# 12     nohair     nofeathers       eggs  ...     nodomestic     nocatsize       Fish
# 18     nohair     nofeathers       eggs  ...     nodomestic       catsize       Fish
#
# [5 rows x 17 columns]

# %%
transacs_class_Fish = []
for i in range(0,len(class_Fish)):
  transacs.append([str(class_Fish.values[i,j]) for j in range(1,16)])
transacs

# %%
asso_class_Fish = list(apriori(transacs_class_Fish,min_support = 0.02, min_confidence = 0.2))
asso_class_Fish

# %% [markdown]
# ## Association ของสัตว์ประเภท Bird

# %%
class_Bird = class_z_merged_dr[class_z_merged_dr['Class_Type']=='Bird']
class_Bird.head()
# Out:
#    hair_group feathers_group eggs_group  ... domestic_group catsize_group Class_Type
# 11     nohair       feathers       eggs  ...       domestic     nocatsize       Bird
# 16     nohair       feathers       eggs  ...     nodomestic     nocatsize       Bird
# 20     nohair       feathers       eggs  ...       domestic     nocatsize       Bird
# 21     nohair       feathers       eggs  ...     nodomestic     nocatsize       Bird
# 23     nohair       feathers       eggs  ...     nodomestic       catsize       Bird
#
# [5 rows x 17 columns]

# %%
transacs_class_Bird = []
for i in range(0,len(class_Bird)):
  transacs.append([str(class_Bird.values[i,j]) for j in range(1,16)])
transacs

# %%
asso_class_Bird = list(apriori(transacs_class_Bird,min_support = 0.02, min_confidence = 0.2))
asso_class_Bird

# %% [markdown]
# ## Association ของสัตว์ประเภท Reptile

# %%
class_Reptile = class_z_merged_dr[class_z_merged_dr['Class_Type']=='Reptile']
class_Reptile.head()
# Out:
#    hair_group feathers_group eggs_group  ... domestic_group catsize_group Class_Type
# 62     nohair     nofeathers       eggs  ...     nodomestic     nocatsize    Reptile
# 76     nohair     nofeathers     noeggs  ...     nodomestic     nocatsize    Reptile
# 80     nohair     nofeathers       eggs  ...     nodomestic     nocatsize    Reptile
# 90     nohair     nofeathers       eggs  ...     nodomestic       catsize    Reptile
# 91     nohair     nofeathers       eggs  ...     nodomestic     nocatsize    Reptile
#
# [5 rows x 17 columns]

# %%
transacs_class_Reptile = []
for i in range(0,len(class_Reptile)):
  transacs.append([str(class_Reptile.values[i,j]) for j in range(1,16)])
transacs
# Out:
# [['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '8legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'noeggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '8legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'noeggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'venomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'eggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'venomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize']]

# %%
asso_class_Reptile = list(apriori(transacs_class_Reptile,min_support = 0.02, min_confidence = 0.2))
asso_class_Reptile
# Out:
# []

# %% [markdown]
# ## Association ของสัตว์ประเภท Amphibian

# %%
class_Amphibian = class_z_merged_dr[class_z_merged_dr['Class_Type']=='Amphibian']
class_Amphibian.head()
# Out:
#    hair_group feathers_group eggs_group  ... domestic_group catsize_group Class_Type
# 25     nohair     nofeathers       eggs  ...     nodomestic     nocatsize  Amphibian
# 26     nohair     nofeathers       eggs  ...     nodomestic     nocatsize  Amphibian
# 52     nohair     nofeathers       eggs  ...     nodomestic     nocatsize  Amphibian
# 89     nohair     nofeathers       eggs  ...     nodomestic     nocatsize  Amphibian
#
# [4 rows x 17 columns]

# %%
transacs_class_Amphibian = []
for i in range(0,len(class_Amphibian)):
  transacs.append([str(class_Amphibian.values[i,j]) for j in range(1,16)])
transacs
# Out:
# [['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '8legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'noeggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '8legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'noeggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'venomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'eggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
# ...
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'venomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize']]

# %%
asso_class_Amphibian = list(apriori(transacs_class_Amphibian,min_support = 0.02, min_confidence = 0.2))
asso_class_Amphibian
# Out:
# []

# %% [markdown]
# ## Association ของสัตว์ประเภท Bug

# %%
class_Bug = class_z_merged_dr[class_z_merged_dr['Class_Type']=='Bug']
class_Bug.head()
# Out:
#    hair_group feathers_group eggs_group  ... domestic_group catsize_group Class_Type
# 24     nohair     nofeathers       eggs  ...     nodomestic     nocatsize        Bug
# 30     nohair     nofeathers       eggs  ...     nodomestic     nocatsize        Bug
# 39       hair     nofeathers       eggs  ...       domestic     nocatsize        Bug
# 40       hair     nofeathers       eggs  ...     nodomestic     nocatsize        Bug
# 42     nohair     nofeathers       eggs  ...     nodomestic     nocatsize        Bug
#
# [5 rows x 17 columns]

# %%
transacs_class_Bug = []
for i in range(0,len(class_Bug)):
  transacs.append([str(class_Bug.values[i,j]) for j in range(1,16)])
transacs

# %%
asso_class_Bug = list(apriori(transacs_class_Bug,min_support = 0.02, min_confidence = 0.2))
asso_class_Bug
# Out:
# []

# %% [markdown]
# ## Association ของสัตว์ประเภท Invertebrate

# %%
class_Invertebrate = class_z_merged_dr[class_z_merged_dr['Class_Type']=='Invertebrate']
class_Invertebrate.head()
# Out:
#    hair_group feathers_group  ... catsize_group    Class_Type
# 13     nohair     nofeathers  ...     nocatsize  Invertebrate
# 14     nohair     nofeathers  ...     nocatsize  Invertebrate
# 15     nohair     nofeathers  ...     nocatsize  Invertebrate
# 46     nohair     nofeathers  ...     nocatsize  Invertebrate
# 53     nohair     nofeathers  ...       catsize  Invertebrate
#
# [5 rows x 17 columns]

# %%
transacs_class_Invertebrate = []
for i in range(0,len(class_Invertebrate)):
  transacs.append([str(class_Invertebrate.values[i,j]) for j in range(1,16)])
transacs
# Out:
# [['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '8legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'noeggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '8legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'noeggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'venomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['hair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['hair',
#   'nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nohair',
#   'nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nohair',
#   'feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'eggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize',
#   'Mammal'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
# ...
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'domestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'fins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'milk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'venomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'novenomous',
#   'fins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'aquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['feathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '2legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'noeggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'nobreathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'nopredator',
#   'toothed',
#   'backbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'domestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'airborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '6legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '8legs',
#   'tail',
#   'nodomestic',
#   'catsize'],
#  ['nofeathers',
#   'noeggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'venomous',
#   'nofins',
#   '8legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'venomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'aquatic',
#   'predator',
#   'notoothed',
#   'nobackbone',
#   'nobreathes',
#   'novenomous',
#   'nofins',
#   '4legs',
#   'tail',
#   'nodomestic',
#   'nocatsize'],
#  ['nofeathers',
#   'eggs',
#   'nomilk',
#   'noairborne',
#   'noaquatic',
#   'nopredator',
#   'notoothed',
#   'nobackbone',
#   'breathes',
#   'novenomous',
#   'nofins',
#   'nolegs',
#   'tail',
#   'nodomestic',
#   'nocatsize']]

# %%
asso_class_Invertebrate = list(apriori(transacs_class_Invertebrate,min_support = 0.0002, min_confidence = 0.02))
asso_class_Invertebrate
# Out:
# []

# %% [markdown]
# # ลองใหม่

# %%
class_z_merged_dr = class_z_merged_dr.groupby(by='Class_Type')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-734d81ccb9d8> in <module>()
# ----> 1 class_z_merged_dr = class_z_merged_dr.groupby(by='Class_Type').mean()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     702
#     703         raise AttributeError(
# --> 704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#     706
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'

# %%
class_z_merged_dr
