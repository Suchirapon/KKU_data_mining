# %% [markdown]
# <a href="https://colab.research.google.com/github/Suchirapon/KKU_data_mining/blob/master/%E0%B8%95%E0%B8%A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![1E1F52A9-F36B-4253-903B-20CAABE64A16.png](data:image/png;base64,...)

# %% [markdown]
# ![A76F7528-3ABB-4387-884D-6C4A431B543C.png](data:image/png;base64,...)

# %% [markdown]
# ![ADA0F221-0088-430F-B2FF-EEBA74882E88.png](data:image/png;base64,...)
